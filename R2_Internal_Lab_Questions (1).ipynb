# %%
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## K-Nearest-Neighbors

# %% [markdown]
# KNN falls in the supervised learning family of algorithms. Informally, this means that we are given a labelled dataset consiting of training observations (x,y) and would like to capture the relationship between x and y. More formally, our goal is to learn a function h:X→Y so that given an unseen observation x, h(x) can confidently predict the corresponding output y.
#
# In this module we will explore the inner workings of KNN, choosing the optimal K values and using KNN from scikit-learn.

# %% [markdown]
# ## Overview
#
# 1.Read the problem statement.
#
# 2.Get the dataset.
#
# 3.Explore the dataset.
#
# 4.Pre-processing of dataset.
#
# 5.Visualization
#
# 6.Transform the dataset for building machine learning model.
#
# 7.Split data into train, test set.
#
# 7.Build Model.
#
# 8.Apply the model.
#
# 9.Evaluate the model.
#
# 10.Finding Optimal K value
#
# 11.Repeat 7,8,9 steps.

# %% [markdown]
# ## Problem statement
#
# ### Dataset
#
# The data set we’ll be using is the Iris Flower Dataset which was first introduced in 1936 by the famous statistician Ronald Fisher and consists of 50 observations from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals.
#
# **Attributes of the dataset:** https://archive.ics.uci.edu/ml/datasets/Iris
#
# **Train the KNN algorithm to be able to distinguish the species from one another given the measurements of the 4 features.**

# %% [markdown]
# ## Question 1
#
# Import the data set and print 10 random rows from the data set

# %%
## Import the datafile
import pandas as pd
dev = pd.read_csv("iris.csv")

# %%
import pandas as pd
import random as rand

# %%
dev.sample(n = 10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 17    18            5.1           3.5            1.4           0.3
# 102  103            7.1           3.0            5.9           2.1
# 134  135            6.1           2.6            5.6           1.4
# 129  130            7.2           3.0            5.8           1.6
# 53    54            5.5           2.3            4.0           1.3
# 37    38            4.9           3.1            1.5           0.1
# 25    26            5.0           3.0            1.6           0.2
# 132  133            6.4           2.8            5.6           2.2
#
#              Species
# 5        Iris-setosa
# 6        Iris-setosa
# 17       Iris-setosa
# 102   Iris-virginica
# 134   Iris-virginica
# 129   Iris-virginica
# 53   Iris-versicolor
# 37       Iris-setosa
# 25       Iris-setosa
# 132   Iris-virginica

# %% [markdown]
# ## Data Pre-processing

# %% [markdown]
# ## Question 2 - Estimating missing values
#
# *Its not good to remove the records having missing values all the time. We may end up loosing some data points. So, we will have to see how to replace those missing values with some estimated values (median) *

# %%
dev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 6 columns):
# Id               152 non-null int64
# SepalLengthCm    151 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     151 non-null float64
# Species          152 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
## To check to check Min value so we can detect missing value if it is either -1 or 0
dev.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  152.000000     151.000000    150.000000     150.000000    151.000000
# mean    76.500000       5.843709      3.054000       3.758667      1.202649
# std     44.022721       0.825314      0.433594       1.764420      0.762185
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.750000       5.100000      2.800000       1.600000      0.300000
# 50%     76.500000       5.800000      3.000000       4.350000      1.300000
# 75%    114.250000       6.400000      3.300000       5.100000      1.800000
# max    152.000000       7.900000      4.400000       6.900000      2.500000

# %%
## to check if any NaN/-1/0/blank cells
dev.head(152)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# 13    14            4.3           3.0            1.1           0.1
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# 16    17            5.4           3.9            1.3           0.4
# 17    18            5.1           3.5            1.4           0.3
# 18    19            5.7           3.8            1.7           0.3
# 19    20            5.1           3.8            1.5           0.3
# 20    21            5.4           3.4            1.7           0.2
# 21    22            5.1           3.7            1.5           0.4
# 22    23            4.6           3.6            1.0           0.2
# 23    24            5.1           3.3            1.7           0.5
# 24    25            4.8           3.4            1.9           0.2
# 25    26            5.0           3.0            1.6           0.2
# 26    27            5.0           3.4            1.6           0.4
# 27    28            5.2           3.5            1.5           0.2
# 28    29            5.2           3.4            1.4           0.2
# 29    30            4.7           3.2            1.6           0.2
# ..   ...            ...           ...            ...           ...
# 122  123            7.7           2.8            6.7           2.0
# 123  124            6.3           2.7            4.9           1.8
# 124  125            6.7           3.3            5.7           2.1
# 125  126            7.2           3.2            6.0           1.8
# 126  127            6.2           2.8            4.8           1.8
# 127  128            6.1           3.0            4.9           1.8
# 128  129            6.4           2.8            5.6           2.1
# 129  130            7.2           3.0            5.8           1.6
# 130  131            7.4           2.8            6.1           1.9
# 131  132            7.9           3.8            6.4           2.0
# 132  133            6.4           2.8            5.6           2.2
# 133  134            6.3           2.8            5.1           1.5
# 134  135            6.1           2.6            5.6           1.4
# 135  136            7.7           3.0            6.1           2.3
# 136  137            6.3           3.4            5.6           2.4
# 137  138            6.4           3.1            5.5           1.8
# 138  139            6.0           3.0            4.8           1.8
# 139  140            6.9           3.1            5.4           2.1
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
# 150  151            5.9           NaN            NaN           NaN
# 151  152            NaN           NaN            NaN           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# 9       Iris-setosa
# 10      Iris-setosa
# 11      Iris-setosa
# 12      Iris-setosa
# 13      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# 16      Iris-setosa
# 17      Iris-setosa
# 18      Iris-setosa
# 19      Iris-setosa
# 20      Iris-setosa
# 21      Iris-setosa
# 22      Iris-setosa
# 23      Iris-setosa
# 24      Iris-setosa
# 25      Iris-setosa
# 26      Iris-setosa
# 27      Iris-setosa
# 28      Iris-setosa
# 29      Iris-setosa
# ..              ...
# 122  Iris-virginica
# 123  Iris-virginica
# 124  Iris-virginica
# 125  Iris-virginica
# 126  Iris-virginica
# 127  Iris-virginica
# 128  Iris-virginica
# 129  Iris-virginica
# 130  Iris-virginica
# 131  Iris-virginica
# 132  Iris-virginica
# 133  Iris-virginica
# 134  Iris-virginica
# 135  Iris-virginica
# 136  Iris-virginica
# 137  Iris-virginica
# 138  Iris-virginica
# 139  Iris-virginica
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
# 150  Iris-virginica
# 151  Iris-virginica
#
# [152 rows x 6 columns]

# %%
## to check if any NaN/-1/0/blank cells
dev.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    1
# SepalWidthCm     2
# PetalLengthCm    2
# PetalWidthCm     1
# Species          0
# dtype: int64

# %% [markdown]
# ##Steps to eliminate NaN

# %%
import numpy as np
dev['SepalLengthCm'].replace(np.nan, inplace=True)

# %%
dev['SepalWidthCm'].replace(np.nan, inplace=True)

# %%
dev['PetalLengthCm'].replace( np.nan, inplace=True)

# %%
dev['PetalWidthCm'].replace( np.nan, inplace=True)

# %%
dev.head(152)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# 13    14            4.3           3.0            1.1           0.1
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# 16    17            5.4           3.9            1.3           0.4
# 17    18            5.1           3.5            1.4           0.3
# 18    19            5.7           3.8            1.7           0.3
# 19    20            5.1           3.8            1.5           0.3
# 20    21            5.4           3.4            1.7           0.2
# 21    22            5.1           3.7            1.5           0.4
# 22    23            4.6           3.6            1.0           0.2
# 23    24            5.1           3.3            1.7           0.5
# 24    25            4.8           3.4            1.9           0.2
# 25    26            5.0           3.0            1.6           0.2
# 26    27            5.0           3.4            1.6           0.4
# 27    28            5.2           3.5            1.5           0.2
# 28    29            5.2           3.4            1.4           0.2
# 29    30            4.7           3.2            1.6           0.2
# ..   ...            ...           ...            ...           ...
# 122  123            7.7           2.8            6.7           2.0
# 123  124            6.3           2.7            4.9           1.8
# 124  125            6.7           3.3            5.7           2.1
# 125  126            7.2           3.2            6.0           1.8
# 126  127            6.2           2.8            4.8           1.8
# 127  128            6.1           3.0            4.9           1.8
# 128  129            6.4           2.8            5.6           2.1
# 129  130            7.2           3.0            5.8           1.6
# 130  131            7.4           2.8            6.1           1.9
# 131  132            7.9           3.8            6.4           2.0
# 132  133            6.4           2.8            5.6           2.2
# 133  134            6.3           2.8            5.1           1.5
# 134  135            6.1           2.6            5.6           1.4
# 135  136            7.7           3.0            6.1           2.3
# 136  137            6.3           3.4            5.6           2.4
# 137  138            6.4           3.1            5.5           1.8
# 138  139            6.0           3.0            4.8           1.8
# 139  140            6.9           3.1            5.4           2.1
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
# 150  151            5.9           3.0            5.1           1.8
# 151  152            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# 9       Iris-setosa
# 10      Iris-setosa
# 11      Iris-setosa
# 12      Iris-setosa
# 13      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# 16      Iris-setosa
# 17      Iris-setosa
# 18      Iris-setosa
# 19      Iris-setosa
# 20      Iris-setosa
# 21      Iris-setosa
# 22      Iris-setosa
# 23      Iris-setosa
# 24      Iris-setosa
# 25      Iris-setosa
# 26      Iris-setosa
# 27      Iris-setosa
# 28      Iris-setosa
# 29      Iris-setosa
# ..              ...
# 122  Iris-virginica
# 123  Iris-virginica
# 124  Iris-virginica
# 125  Iris-virginica
# 126  Iris-virginica
# 127  Iris-virginica
# 128  Iris-virginica
# 129  Iris-virginica
# 130  Iris-virginica
# 131  Iris-virginica
# 132  Iris-virginica
# 133  Iris-virginica
# 134  Iris-virginica
# 135  Iris-virginica
# 136  Iris-virginica
# 137  Iris-virginica
# 138  Iris-virginica
# 139  Iris-virginica
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
# 150  Iris-virginica
# 151  Iris-virginica
#
# [152 rows x 6 columns]

# %% [markdown]
# ## Question 3 - Dealing with categorical data
#
# Change all the classes to numericals (0to2).

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from scipy.stats import zscore
from sklearn.preprocessing import Imputer
from sklearn.metrics import accuracy_score
import seaborn as sns
import os
# %matplotlib inline

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-121-918a104688fd> in <module>
#       1 from sklearn.model_selection import train_test_split
#       2 independent_variables=dev[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]
# ----> 3 dependent_variables_df["Species"]
#
# NameError: name 'dependent_variables_df' is not defined

# %% [markdown]
# # Question 4
#
# *Observe the association of each independent variable with target variable and drop variables from feature set having correlation in range -0.1 to 0.1 with target variable.*

# %%
dev.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.704110     -0.392693       0.879291
# SepalLengthCm  0.704110       1.000000     -0.109468       0.869096
# SepalWidthCm  -0.392693      -0.109468      1.000000      -0.420122
# PetalLengthCm  0.879291       0.869096     -0.420122       1.000000
# PetalWidthCm   0.896279       0.815297     -0.356345       0.963045
#
#                PetalWidthCm
# Id                 0.896279
# SepalLengthCm      0.815297
# SepalWidthCm      -0.356345
# PetalLengthCm      0.963045
# PetalWidthCm       1.000000

# %% [markdown]
# ## Question 5
#
# *Observe the independent variables variance and drop such variables having no variance or almost zero variance(variance < 0.1). They will be having almost no influence on the classification.*

# %%
dev.var()
# Out:
# Id               1938.000000
# SepalLengthCm       0.676653
# SepalWidthCm        0.185552
# PetalLengthCm       3.095462
# PetalWidthCm        0.579427
# dtype: float64

# %% [markdown]
# ## Question 6
#
# *Plot the scatter matrix for all the variables.*

# %%
pd.plotting.scatter_matrix(dev)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BA4B1860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BA732B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BA7ABDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BAA8D080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BAA502E8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BA644710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BA7DEC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BA694278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BA6942B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BA873D30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BA8A02E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BA8C2860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BA8E8DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BA916390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BA938908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BA95DE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BA98D438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BA9B29B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BAC99F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BACC94E0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BACEFA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BAD18FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BAD47588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BAD6FB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B9BA4BF128>]],
#       dtype=object)

# %% [markdown]
# ## Split the dataset into training and test sets
#
# ## Question 7
#
# *Split the dataset into training and test sets with 80-20 ratio.*

# %%
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
x=["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]
y=['Species']

# %%
from sklearn.model_selection import train_test_split
independent_variables=dev[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]
dependent_variables=dev["Species"]

# %%
x_train, x_test, y_train, y_test = train_test_split(independent_variables, dependent_variables , test_size = 0.2)

# %%
y_test.shape
# Out:
# (31,)

# %%
x_test.shape
# Out:
# (31, 4)

# %%
x_train.shape
# Out:
# (121, 4)

# %%
y_train.shape
# Out:
# (121,)

# %% [markdown]
# ## Question 8 - Model
#
# *Build the model and train and test on training and test sets respectively using **scikit-learn**. Print the Accuracy of the model with different values of **k=3,5,9**.*
#
# **Hint:** For accuracy you can check **accuracy_score()** in scikit-learn

# %% [markdown]
# ## Question 9 - Finding Optimal value of k.
#
# Run the KNN with no of neighbours to be 1,3,5..19 and *Find the **optimal number of neighbours** from the above list using the Miss classification error

# %% [markdown]
# Hint:
#
# Misclassification error (MSE) = 1 - Test accuracy score. Calculated MSE for each model with neighbours = 1,3,5...19 and find the model with lowest MSE

# %% [markdown]
# ## Question 10
#
# *Plot misclassification error vs k (with k value on X-axis) using matplotlib.*

# %% [markdown]
# ### Question 11: Read the data given in bc2.csv file

# %% [markdown]
# ### Question 12: Observe the no.of records in dataset and type of each feature

# %% [markdown]
# ### Question 13: Use summary statistics to check if missing values, outlier and encoding treament is necessary

# %% [markdown]
# ### Check Missing Values

# %% [markdown]
# ### Question 14: Check how many `?` there in Bare Nuclei feature (they are also unknown or missing values). Replace them with the top value of the describe function of Bare Nuclei feature.
#
# #### Check include='all' parameter in describe function

# %% [markdown]
# ### Question 15: Find the distribution of target variable (Class)

# %% [markdown]
# #### Plot the distribution of target variable using histogram

# %% [markdown]
# ### convert the datatype of Bare Nuclei to `int`

# %% [markdown]
# ### Question 16: Standardization of Data

# %% [markdown]
# ### Question 17: Plot Scatter Matrix to understand the distribution of variables and check if any variables are collinear and drop one of them.

# %% [markdown]
# ### Question 18: Divide the dataset into feature set and target set

# %% [markdown]
# ### Divide the Training and Test sets in 70:30

# %% [markdown]
# ## Question 19 - Finding Optimal value of k
#
# Run the KNN with no of neighbours to be 1,3,5..19 and *Find the **optimal number of neighbours** from the above list using the Mis classification error

# %% [markdown]
# Hint:
#
# Misclassification error (MSE) = 1 - Test accuracy score. Calculated MSE for each model with neighbours = 1,3,5...19 and find the model with lowest MSE

# %% [markdown]
# ### Question 20: Print the optimal number of neighbors
