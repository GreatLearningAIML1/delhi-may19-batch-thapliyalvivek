# %%
import numpy as np
from scipy import stats 
from scipy.stats import ttest_ind
from scipy.stats import t
from statsmodels.stats.power import ttest_power

# %%
data=pd.read_csv("titan.csv")

# %%
## EDA

data.describe().T

## Mean of Old Scheme-68.03, New Scheme-72.03
# Out:
#                            count       mean        std   min    25%   50%  \
# SALESPERSON                 30.0  15.500000   8.803408   1.0   8.25  15.5
# Old Scheme (in thousands)   30.0  68.033333  20.455980  28.0  54.00  67.0
# New Scheme (in thousands)   30.0  72.033333  24.062395  32.0  55.00  74.0
#
#                              75%    max
# SALESPERSON                22.75   30.0
# Old Scheme (in thousands)  81.50  110.0
# New Scheme (in thousands)  85.75  122.0

# %%
old=np.array([57,103,59,75,84,73,35,110,44,82,67,64,78,53,41,39,80,87,73,65,28,62,49,84,63,77,67,101,91,50])
new=np.array([62,122,54,82,84,86,32,104,38,107,84,85,99,39,34,58,73,53,66,78,41,71,38,95,81,58,75,94,100,68])

# %%
#Point1. Find Mean
data['Old Scheme (in thousands)'].mean()
# Out:
# 68.03333333333333

# %%
#Point1. Fine Mean
data['New Scheme (in thousands)'].mean()
# Out:
# 72.03333333333333

# %%
old_scheme = data['Old Scheme (in thousands)']
new_scheme = data['New Scheme (in thousands)']

# %%
#Point2. Use the five percent significance test over the data to determine the p value to check new scheme has significantly raised outputs?

t_statistic,p_value=stats.ttest_rel(old_scheme,new_scheme)
print(t_statistic,p_value)
# Out:
# -1.5559143823544377 0.13057553961337662

# %%
#Point3. What conclusion does the test (p-value) lead to?

print("As we can see the P value of is more than 0.05, hence we can say that there is no significant change in output")
# Out:
# As we can see the P value of is more than 0.05, hence we can say that there is no significant change in output

# %%
# Point 4.a
print("\nProb of Type I Error=",0.05)
# Out:
# Prob of Type I Error= 0.05

# %%
#Point 4.b
t_statistic,p_value=stats.ttest_rel(old_scheme,new_scheme)

# %%
# Point 4.c
Zstats = (5)/np.std(new_scheme)
ttest_power(Zstats,nobs=len(np.array(old_scheme))-1,alpha=0.05,alternative='larger')
# Out:
# 0.29660245254588957
