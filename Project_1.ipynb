# %%
## Import pandas & read data set

import pandas as pd
Dev = pd.read_csv("Laliga.csv")

# %%
## Replace '-' with '0'
Dev=Dev.replace("-","0")

# %%
Dev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 20 columns):
# Pos              61 non-null int64
# Team             61 non-null object
# Seasons          61 non-null int64
# Points           61 non-null object
# GamesPlayed      61 non-null object
# GamesWon         61 non-null object
# GamesDrawn       61 non-null object
# GamesLost        61 non-null object
# GoalsFor         61 non-null object
# GoalsAgainst     61 non-null object
# Champion         61 non-null object
# Runner-up        61 non-null object
# Third            61 non-null object
# Fourth           61 non-null object
# Fifth            61 non-null object
# Sixth            61 non-null object
# T                61 non-null object
# Debut            61 non-null object
# Since/LastApp    61 non-null object
# BestPosition     61 non-null int64
# dtypes: int64(3), object(17)
# memory usage: 9.6+ KB

# %%
Dev["Points"] = Dev["Points"].astype(int)

# %%
Dev.columns
# Out:
# Index(['Pos', 'Team', 'Seasons', 'Points', 'GamesPlayed', 'GamesWon',
#        'GamesDrawn', 'GamesLost', 'GoalsFor', 'GoalsAgainst', 'Champion',
#        'Runner-up', 'Third', 'Fourth', 'Fifth', 'Sixth', 'T', 'Debut',
#        'Since/LastApp', 'BestPosition'],
#       dtype='object')

# %%
cols=['GamesPlayed', 'GamesWon', 'GamesDrawn', 'GamesLost', 'GoalsFor', 'GoalsAgainst', 'Champion', 'Runner-up', 'Third', 'Fourth', 'Fifth', 'Sixth', 'T']

# %%
for a in cols:
    Dev[a]=Dev[a].astype(int)

# %%
Dev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 20 columns):
# Pos              61 non-null int64
# Team             61 non-null object
# Seasons          61 non-null int64
# Points           61 non-null int32
# GamesPlayed      61 non-null int32
# GamesWon         61 non-null int32
# GamesDrawn       61 non-null int32
# GamesLost        61 non-null int32
# GoalsFor         61 non-null int32
# GoalsAgainst     61 non-null int32
# Champion         61 non-null int32
# Runner-up        61 non-null int32
# Third            61 non-null int32
# Fourth           61 non-null int32
# Fifth            61 non-null int32
# Sixth            61 non-null int32
# T                61 non-null int32
# Debut            61 non-null object
# Since/LastApp    61 non-null object
# BestPosition     61 non-null int64
# dtypes: int32(14), int64(3), object(3)
# memory usage: 6.3+ KB

# %%
Dev.Debut
# Out:
# 0        1929
# 1        1929
# 2        1929
# 3     1931-32
# 4        1929
# 5     1934-35
# 6        1929
# 7        1929
# 8     1939-40
# 9     1932-33
# 10    1941-42
# 11    1939-40
# 12    1948-49
# 13       1929
# 14    1944-45
# 15    1935-36
# 16    1949-50
# 17    1933-34
# 18    1960-61
# 19    1951-52
# 20    1998-99
# 21    1941-42
# 22    1977-78
# 23    1959-60
# 24    2004-05
# 25    1935-36
# 26    1961-62
# 27    1940-41
# 28    1930-31
# 29    1963-64
#        ...
# 31    1943-44
# 32    1977-78
# 33    1987-88
# 34    1941-42
# 35    1991-92
# 36    2007-08
# 37    1962-63
# 38    1994-95
# 39    1978-79
# 40    1971-72
# 41    1963-64
# 42    1999-00
# 43    2014-15
# 44       1929
# 45    1990-91
# 46    1947-48
# 47    1996-97
# 48    1995-96
# 49    1945-46
# 50    1953-54
# 51       1929
# 52    1979-80
# 53       1929
# 54    1950-51
# 55    2016-17
# 56    2009-10
# 57    1956-57
# 58    1951-52
# 59    1955-56
# 60    2017-18
# ...

# %%
Abs = "1979-80"

# %%
Abs.split('-')[0]
# Out:
# '1979'

# %%
Rbs="1929"

# %%
Rbs.split('-')[0]
# Out:
# '1929'

# %%
Dev["Debut"]=Dev["Debut"].apply(lambda x:int(x.split('-')[0]))

# %%
Dev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 20 columns):
# Pos              61 non-null int64
# Team             61 non-null object
# Seasons          61 non-null int64
# Points           61 non-null int32
# GamesPlayed      61 non-null int32
# GamesWon         61 non-null int32
# GamesDrawn       61 non-null int32
# GamesLost        61 non-null int32
# GoalsFor         61 non-null int32
# GoalsAgainst     61 non-null int32
# Champion         61 non-null int32
# Runner-up        61 non-null int32
# Third            61 non-null int32
# Fourth           61 non-null int32
# Fifth            61 non-null int32
# Sixth            61 non-null int32
# T                61 non-null int32
# Debut            61 non-null int64
# Since/LastApp    61 non-null object
# BestPosition     61 non-null int64
# dtypes: int32(14), int64(4), object(2)
# memory usage: 6.3+ KB

# %%
Dev["Since/LastApp"]=Dev["Since/LastApp"].apply(lambda x:int(x.split('-')[0]))

# %%
Dev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 20 columns):
# Pos              61 non-null int64
# Team             61 non-null object
# Seasons          61 non-null int64
# Points           61 non-null int32
# GamesPlayed      61 non-null int32
# GamesWon         61 non-null int32
# GamesDrawn       61 non-null int32
# GamesLost        61 non-null int32
# GoalsFor         61 non-null int32
# GoalsAgainst     61 non-null int32
# Champion         61 non-null int32
# Runner-up        61 non-null int32
# Third            61 non-null int32
# Fourth           61 non-null int32
# Fifth            61 non-null int32
# Sixth            61 non-null int32
# T                61 non-null int32
# Debut            61 non-null int64
# Since/LastApp    61 non-null int64
# BestPosition     61 non-null int64
# dtypes: int32(14), int64(5), object(1)
# memory usage: 6.3+ KB

# %%
## Print all the teams which have started playing between 1930-1980.

Dev.loc[(Dev["Debut"]>=1930)&(Dev["Debut"]<=1980)]
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 3     4             Valencia       82    3386         2664      1187
# 5     6              Sevilla       73    2819         2408       990
# 8     9             Zaragoza       58    2109         1986       698
# 9    10           Real Betis       51    1884         1728       606
# 10   11  Deportivo La Coruna       45    1814         1530       563
# 11   12           Celta Vigo       51    1789         1698       586
# 12   13           Valladolid       42    1471         1466       463
# 14   15       Sporting Gijon       43    1389         1458       471
# 15   16              Osasuna       37    1351         1318       426
# 16   17               Malaga       36    1314         1255       390
# 17   18               Oviedo       38    1174         1192       408
# 18   19             Mallorca       27    1148          988       333
# 19   20           Las Palmas       33    1020         1096       367
# ...

# %%
## Print the list of teams which came Top 5 in terms of points
Dev.sort_values("Points",ascending=False)
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0     1          Real Madrid       86    4385         2762      1647
# 1     2            Barcelona       86    4262         2762      1581
# 2     3      Atletico Madrid       80    3442         2614      1241
# 3     4             Valencia       82    3386         2664      1187
# 4     5      Athletic Bilbao       86    3368         2762      1209
# 5     6              Sevilla       73    2819         2408       990
# 6     7             Espanyol       82    2792         2626       948
# 7     8        Real Sociedad       70    2573         2302       864
# 8     9             Zaragoza       58    2109         1986       698
# 9    10           Real Betis       51    1884         1728       606
# 10   11  Deportivo La Coruna       45    1814         1530       563
# 11   12           Celta Vigo       51    1789         1698       586
# 12   13           Valladolid       42    1471         1466       463
# ...

# %%
Dev1=Dev.sort_values("Points",ascending=False)

# %%
Dev1.head()
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 0    1      Real Madrid       86    4385         2762      1647         552
# 1    2        Barcelona       86    4262         2762      1581         573
# 2    3  Atletico Madrid       80    3442         2614      1241         598
# 3    4         Valencia       82    3386         2664      1187         616
# 4    5  Athletic Bilbao       86    3368         2762      1209         633
#
#    GamesLost  GoalsFor  GoalsAgainst  Champion  Runner-up  Third  Fourth  \
# 0        563      5947          3140        33         23      8       8
# 1        608      5900          3114        25         25     12      12
# 2        775      4534          3309        10          8     16       9
# 3        861      4398          3469         6          6     10      11
# 4        920      4631          3700         8          7     10       5
#
#    Fifth  Sixth   T  Debut  Since/LastApp  BestPosition
# ...

# %%
## Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. Using the same function, find the team which has maximum and minimum goal difference.

Dev["Goal_diff_count"] = Dev["GoalsFor"]-Dev["GoalsAgainst"]

# %%
Dev
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0     1          Real Madrid       86    4385         2762      1647
# 1     2            Barcelona       86    4262         2762      1581
# 2     3      Atletico Madrid       80    3442         2614      1241
# 3     4             Valencia       82    3386         2664      1187
# 4     5      Athletic Bilbao       86    3368         2762      1209
# 5     6              Sevilla       73    2819         2408       990
# 6     7             Espanyol       82    2792         2626       948
# 7     8        Real Sociedad       70    2573         2302       864
# 8     9             Zaragoza       58    2109         1986       698
# 9    10           Real Betis       51    1884         1728       606
# 10   11  Deportivo La Coruna       45    1814         1530       563
# 11   12           Celta Vigo       51    1789         1698       586
# 12   13           Valladolid       42    1471         1466       463
# ...

# %%
Dev["Goal_diff_count"].max()
# Out:
# 2807

# %%
Dev["Goal_diff_count"].min()
# Out:
# -525

# %%
## Create a new column with name “Winning Percent” and append it to the data set

Dev["Winning_Percent"] = (Dev["GamesWon"]/Dev["GamesPlayed"])*100

# %%
Dev
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0     1          Real Madrid       86    4385         2762      1647
# 1     2            Barcelona       86    4262         2762      1581
# 2     3      Atletico Madrid       80    3442         2614      1241
# 3     4             Valencia       82    3386         2664      1187
# 4     5      Athletic Bilbao       86    3368         2762      1209
# 5     6              Sevilla       73    2819         2408       990
# 6     7             Espanyol       82    2792         2626       948
# 7     8        Real Sociedad       70    2573         2302       864
# 8     9             Zaragoza       58    2109         1986       698
# 9    10           Real Betis       51    1884         1728       606
# 10   11  Deportivo La Coruna       45    1814         1530       563
# 11   12           Celta Vigo       51    1789         1698       586
# 12   13           Valladolid       42    1471         1466       463
# ...

# %%
Dev["Winning_Percent"]
# Out:
# 0     59.630702
# 1     57.241130
# 2     47.475134
# 3     44.557057
# 4     43.772629
# 5     41.112957
# 6     36.100533
# 7     37.532580
# 8     35.146022
# 9     35.069444
# 10    36.797386
# 11    34.511190
# 12    31.582538
# 13    31.722689
# 14    32.304527
# 15    32.321700
# 16    31.075697
# 17    34.228188
# 18    33.704453
# 19    33.485401
# 20    41.176471
# 21    29.380054
# 22    28.987730
# 23    29.941003
# 24    32.236842
# 25    29.299363
# 26    31.376518
# 27    24.744027
# 28    32.894737
# 29    28.109453
#         ...
# 31    30.281690
# 32    23.214286
# 33    27.745665
# 34    30.838323
# 35    28.148148
# 36    27.192982
# 37    29.078014
# 38    32.500000
# 39    26.881720
# 40    28.921569
# 41    29.444444
# 42    24.342105
# 43    30.701754
# 44    33.076923
# 45    22.807018
# 46    29.310345
# 47    25.000000
# 48    23.750000
# 49    27.777778
# 50    32.222222
# 51    29.166667
# 52    25.000000
# 53    33.333333
# 54    19.117647
# ...

# %%
Dev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 22 columns):
# Pos                61 non-null int64
# Team               61 non-null object
# Seasons            61 non-null int64
# Points             61 non-null int32
# GamesPlayed        61 non-null int32
# GamesWon           61 non-null int32
# GamesDrawn         61 non-null int32
# GamesLost          61 non-null int32
# GoalsFor           61 non-null int32
# GoalsAgainst       61 non-null int32
# Champion           61 non-null int32
# Runner-up          61 non-null int32
# Third              61 non-null int32
# Fourth             61 non-null int32
# Fifth              61 non-null int32
# Sixth              61 non-null int32
# T                  61 non-null int32
# Debut              61 non-null int64
# Since/LastApp      61 non-null int64
# BestPosition       61 non-null int64
# Goal_diff_count    61 non-null int32
# Winning_Percent    61 non-null float64
# ...

# %%
# Add column with Name Winning_Percent

Dev['Winning_Percent'] = Dev['Winning_Percent']

# %%
Dev
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0     1          Real Madrid       86    4385         2762      1647
# 1     2            Barcelona       86    4262         2762      1581
# 2     3      Atletico Madrid       80    3442         2614      1241
# 3     4             Valencia       82    3386         2664      1187
# 4     5      Athletic Bilbao       86    3368         2762      1209
# 5     6              Sevilla       73    2819         2408       990
# 6     7             Espanyol       82    2792         2626       948
# 7     8        Real Sociedad       70    2573         2302       864
# 8     9             Zaragoza       58    2109         1986       698
# 9    10           Real Betis       51    1884         1728       606
# 10   11  Deportivo La Coruna       45    1814         1530       563
# 11   12           Celta Vigo       51    1789         1698       586
# 12   13           Valladolid       42    1471         1466       463
# ...

# %%
##replace NaN

import numpy as np
Dev['Winning_Percent'].replace(np.NaN, inplace=True)

# %%
Dev
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0     1          Real Madrid       86    4385         2762      1647
# 1     2            Barcelona       86    4262         2762      1581
# 2     3      Atletico Madrid       80    3442         2614      1241
# 3     4             Valencia       82    3386         2664      1187
# 4     5      Athletic Bilbao       86    3368         2762      1209
# 5     6              Sevilla       73    2819         2408       990
# 6     7             Espanyol       82    2792         2626       948
# 7     8        Real Sociedad       70    2573         2302       864
# 8     9             Zaragoza       58    2109         1986       698
# 9    10           Real Betis       51    1884         1728       606
# 10   11  Deportivo La Coruna       45    1814         1530       563
# 11   12           Celta Vigo       51    1789         1698       586
# 12   13           Valladolid       42    1471         1466       463
# ...

# %%
## Print the top 5 teams which has the highest Winning percentage

Dev.sort_values("Winning_Percent",ascending=False)
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0     1          Real Madrid       86    4385         2762      1647
# 1     2            Barcelona       86    4262         2762      1581
# 2     3      Atletico Madrid       80    3442         2614      1241
# 3     4             Valencia       82    3386         2664      1187
# 4     5      Athletic Bilbao       86    3368         2762      1209
# 20   21           Villarreal       17     970          646       266
# 5     6              Sevilla       73    2819         2408       990
# 7     8        Real Sociedad       70    2573         2302       864
# 10   11  Deportivo La Coruna       45    1814         1530       563
# 6     7             Espanyol       82    2792         2626       948
# 8     9             Zaragoza       58    2109         1986       698
# 9    10           Real Betis       51    1884         1728       606
# 11   12           Celta Vigo       51    1789         1698       586
# ...

# %%
Dev2=Dev.sort_values("Winning_Percent",ascending=False)

# %%
## Print the top 5 teams which has the highest Winning percentage

Dev2.head()
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 0    1      Real Madrid       86    4385         2762      1647         552
# 1    2        Barcelona       86    4262         2762      1581         573
# 2    3  Atletico Madrid       80    3442         2614      1241         598
# 3    4         Valencia       82    3386         2664      1187         616
# 4    5  Athletic Bilbao       86    3368         2762      1209         633
#
#    GamesLost  GoalsFor  GoalsAgainst  ...  Third  Fourth  Fifth  Sixth   T  \
# 0        563      5947          3140  ...      8       8      3      4  79
# 1        608      5900          3114  ...     12      12      4      6  83
# 2        775      4534          3309  ...     16       9      7      6  56
# 3        861      4398          3469  ...     10      11     10      7  50
# 4        920      4631          3700  ...     10       5      8     10  49
#
# ...

# %%
## Group teams based on their “Best position” and print the sum of their points for all positions 

import pandas as pd
Best=Dev.groupby("BestPosition")

# %%
Best.first()
# Out:
#               Pos              Team  Seasons  Points  GamesPlayed  GamesWon  \
# BestPosition
# 1               1       Real Madrid       86    4385         2762      1647
# 2               9          Zaragoza       58    2109         1986       698
# 3               7          Espanyol       82    2792         2626       948
# 4              12        Celta Vigo       51    1789         1698       586
# 5              24             Elche       21     606          678       203
# 6              22           Granada       23     667          742       218
# 7              31         Salamanca       12     375          423       123
# 8              23    Rayo Vallecano       17     662          652       189
# 9              46       Real Burgos        3      96          114        26
# 10             39        Compostela        4     190          160        52
# 11             28            Murcia       18     445          586       145
# ...

# %%
Best=Dev.groupby("BestPosition").sum()

# %%
Best['Points']
# Out:
# BestPosition
# 1     27933
# 2      6904
# 3      5221
# 4      6563
# 5      1884
# 6      2113
# 7      1186
# 8      1134
# 9        96
# 10      450
# 11      445
# 12      511
# 14       71
# 15       14
# 16       81
# 17      266
# 19       81
# 20       34
# Name: Points, dtype: int32
